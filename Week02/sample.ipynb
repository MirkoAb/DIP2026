# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
from turtledemo.round_dance import stop

from pexpect.replwrap import python

print("Hello World!1111")
img = cv.2.imread ()
# Out:
#   Cell In[5], line 4
#     img = cv.2.imread ()
#             ^
# SyntaxError: invalid syntax

# %%
pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 15.6 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: /Users/mirjalol/PycharmProjects/JupyterProject/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
color_image = cv2.imread('fruit basket.jpg')
# Out:
# [ WARN:0@17.664] global loadsave.cpp:278 findDecoder imread_('fruit basket.jpg'): can't open/read file: check file path/integrity

# %%
color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')

# %%
cv2.imshow('color image',color_image)

# %%
cv2.imshow('color image',color_image)

# %%
cv2.imshow('color image',color_image)

# %%
cv2.imshow('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg',color_image)

# %%
cv2.imshow('/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp',color_image)

# %%
color_image = cv2.imread(
    '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
)

cv2.imshow('Image', color_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img.shape
#
# NameError: name 'img' is not defined

# %%
color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')
#
# NameError: name 'cv2' is not defined

# %%
color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')
#
# NameError: name 'cv2' is not defined

# %%
color_image = cv2.imread(
    '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
)

cv2.imshow('Image', color_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 color_image = cv2.imread(
#       2     '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
#       3 )
#       5 cv2.imshow('Image', color_image)
#       6 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined

# %%
color_image = cv2.imread(
    '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
)

cv2.imshow('Image', color_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 color_image = cv2.imread(
#       2     '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
#       3 )
#       5 cv2.imshow('Image', color_image)
#       6 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined

# %%
import cv2

# %%
color_image = cv2.imread('/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg')

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 img.shape
#
# NameError: name 'img' is not defined

# %%
img = cv2.imread(
    '/Users/mirjalol/Downloads/single-fresh-red-strawberry-on-table-green-background-food-fruit-sweet-macro-juicy-plant-image-photo.jpg'
)

img.shape
# Out:
# (350, 642, 3)

# %%
ging = cv2. imread("E: \Courses\Spring 2025\F23 lectures \Week 1\CAU.png")
CNimg = cv2. cvt@plor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)
# Out:
# [ WARN:0@307.960] global loadsave.cpp:278 findDecoder imread_('E: \Courses\Spring 2025\F23 lectures \Week 1\CAU.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 ging = cv2. imread("E: \Courses\Spring 2025\F23 lectures \Week 1\CAU.png")
# ----> 2 CNimg = cv2. cvt@plor (gimg, cv2.COLOR_BGR2GRAY)
#       3 cv2. imshow("Converted Image", CNimg)
#       4 cv2.waitKey(0)
#
# AttributeError: module 'cv2' has no attribute 'cvt'

# %%
ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvt@plor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
# ----> 2 CNimg = cv2. cvt@plor (gimg, cv2.COLOR_BGR2GRAY)
#       3 cv2. imshow("Converted Image", CNimg)
#       4 cv2.waitKey(0)
#
# AttributeError: module 'cv2' has no attribute 'cvt'

# %%
ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
# ----> 2 CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
#       3 cv2. imshow("Converted Image", CNimg)
#       4 cv2.waitKey(0)
#
# NameError: name 'gimg' is not defined

# %%
gimg = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)

# %%
ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
#       2 CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
#       3 cv2. imshow("Converted Image", CNimg)
#
# NameError: name 'cv2' is not defined

# %%
import cv2

# %%
ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 ging = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
# ----> 2 CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
#       3 cv2. imshow("Converted Image", CNimg)
#       4 cv2.waitKey(0)
#
# NameError: name 'gimg' is not defined

# %%
gimg = cv2. imread("/Users/mirjalol/Downloads/traveler-woman-arms-raised-triumph-260nw-2457990309.jpg.webp")
CNimg = cv2. cvtColor (gimg, cv2.COLOR_BGR2GRAY)
cv2. imshow("Converted Image", CNimg)
cv2.waitKey(0)

# %%
import cv2
